# %% [markdown]
# ## Data Scraping from YouTube using Data API

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ### Objective:
# #### For a given "YouTube channel ID"  we need to return the below mentioned fields for each video in it.
# #### Our final data should have
#         1. video_id
#         2. channel_id
#         3. published_date
#         4. video_title
#         5. video_description
#         6. likes
#         7. dislikes
#         8. views
#         9. comment_count
#
# #### Note: we need to scrape the data legally

# %%
#Our final data should be saved in this Data Frame
data_df = pd.DataFrame(columns=['video_id','channel_id','published_date',
                             'video_title','video_description',
                             'likes','dislikes','views','comment_count'])
data_df.head()
# Out:
# Empty DataFrame
# Columns: [video_id, channel_id, published_date, video_title, video_description, likes, dislikes, views, comment_count]
# Index: []

# %% [markdown]
# #### ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### To access this API
# #### 1. We need a API key (free of cost)
# (Goto: https://console.developers.google.com/apis/)

# %%
api_key = 'AIzaSyCI9-pNO5gYGPT8u2VUY709ALdD_2GX-5s' #Replace with your own API KEY

# %% [markdown]
# #### 2. We need to call API (as per our needs)
#
# (Goto:https://developers.google.com/youtube/v3)

# %%
#First we will check API response with "ChannelID"
channel_Id = 'UCpVm7bg6pXKo1Pr6k5kxG9A'
url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&key={api_key}&id={channel_Id}"
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/channels?part=statistics&key=AIzaSyCI9-pNO5gYGPT8u2VUY709ALdD_2GX-5s&id=UCpVm7bg6pXKo1Pr6k5kxG9A

# %%
response_data = requests.get(url)
json_data = json.loads(response_data.text)

# %%
#Now we will check the API response with "Video ID"
video_Id = "RYJX_ovILjk"
url = f"https://www.googleapis.com/youtube/v3/videos?part=statistics,snippet&key={api_key}&id={video_Id}"
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/videos?part=statistics,snippet&key=AIzaSyCI9-pNO5gYGPT8u2VUY709ALdD_2GX-5s&id=RYJX_ovILjk

# %%
response_data = requests.get(url)
json_data = json.loads(response_data.text)

# %%
json_data
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '1SKocShdaa-Qw1eELVDMH0RLgyU',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'h-xzadUS0Wey5mTzDNEBz-JI2wU',
#    'id': 'RYJX_ovILjk',
#    'snippet': {'publishedAt': '2020-08-17T15:00:11Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'A Case of Mistaken Identity | Shark vs Surfer',
#     'description': "A surfer off the coast of Oahu was attacked by a tiger shark in 2017, but why did this attack occur? Professor Stephen Kajiura explains how it may have been a case of mistaken identity.\n➡ Subscribe: http://bit.ly/NatGeoSubscribe\n➡ Get more SharkFest: https://on.natgeo.com/2kISTAt\n\nAbout SharkFest:\nPut on your wetsuit to swim with the sharpest of the sea. This is the one-stop-show-shop for all things shark. No fuss, no muss, just killer episodes.\n\nAbout National Geographic:\nNational Geographic is the world's premium destination for science, exploration, and adventure. Through their world-class scientists, photographers, journalists, and filmmakers, Nat Geo gets you closer to the stories that matter and past the edge of what's possible.\n\nGet More National Geographic:\nOfficial Site: http://bit.ly/NatGeoOfficialSite\nFacebook: http://bit.ly/FBNatGeo\nTwitter: http://bit.ly/NatGeoTwitter\nInstagram: http://bit.ly/NatGeoInsta\n\nA Case of Mistaken Identity | Shark vs Surfer\nhttps://youtu.be/RYJX_ovILjk\n\nNational Geographic\nhttps://www.youtube.com/natgeo",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RYJX_ovILjk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RYJX_ovILjk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RYJX_ovILjk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/RYJX_ovILjk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/RYJX_ovILjk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'National Geographic',
#     'tags': ['national geographic',
#      'nat geo',
#      'natgeo',
#      'animals',
#      'wildlife',
#      'science',
#      'explore',
#      'discover',
#      'survival',
#      'nature',
#      'documentary',
#      'SharkFest',
#      'PLivjPDlt6ApRiBHpsyXWG22G8RPNZ6jlb',
#      'PLivjPDlt6ApTjurXykShuUqp7LQcj9s8s',
#      'PLivjPDlt6ApQjt4sNnabi7FWVU9-Bh_2t',
#      'Shark vs Surfer',
#      'shark vs surfers',
#      'shark vs surfer nat geo',
#      'shark attacks surfer',
#      'sharkfest 2020 nat geo',
#      'sharkfest 2020',
#      'sharkfest nat geo wild',
#      'sharkfest national geographic',
#      'SharkFest nat geo',
#      'Stephen Kajiura'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'A Case of Mistaken Identity | Shark vs Surfer',
#      'description': "A surfer off the coast of Oahu was attacked by a tiger shark in 2017, but why did this attack occur? Professor Stephen Kajiura explains how it may have been a case of mistaken identity.\n➡ Subscribe: http://bit.ly/NatGeoSubscribe\n➡ Get more SharkFest: https://on.natgeo.com/2kISTAt\n\nAbout SharkFest:\nPut on your wetsuit to swim with the sharpest of the sea. This is the one-stop-show-shop for all things shark. No fuss, no muss, just killer episodes.\n\nAbout National Geographic:\nNational Geographic is the world's premium destination for science, exploration, and adventure. Through their world-class scientists, photographers, journalists, and filmmakers, Nat Geo gets you closer to the stories that matter and past the edge of what's possible.\n\nGet More National Geographic:\nOfficial Site: http://bit.ly/NatGeoOfficialSite\nFacebook: http://bit.ly/FBNatGeo\nTwitter: http://bit.ly/NatGeoTwitter\nInstagram: http://bit.ly/NatGeoInsta\n\nA Case of Mistaken Identity | Shark vs Surfer\nhttps://youtu.be/RYJX_ovILjk\n\nNational Geographic\nhttps://www.youtube.com/natgeo"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '45126',
#     'likeCount': '1183',
#     'dislikeCount': '53',
#     'favoriteCount': '0',
#     'commentCount': '129'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %% [markdown]
# ### Now Let's work on our Objective

# %%
url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_Id}&maxResults=50"
print(url)
response_data = requests.get(url)
json_data = json.loads(response_data.text)
# Out:
# https://www.googleapis.com/youtube/v3/search?key=AIzaSyCI9-pNO5gYGPT8u2VUY709ALdD_2GX-5s&part=snippet&channelId=UCpVm7bg6pXKo1Pr6k5kxG9A&maxResults=50

# %%
json_data
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'wFoGjqRhgqFTmhL3JukwB7R0LU8',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'IN',
#  'pageInfo': {'totalResults': 9778, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'xC_-rVaYCFv38fKVi6kUFc0l_a4',
#    'id': {'kind': 'youtube#video', 'videoId': 'BL4dnvBytLA'},
#    'snippet': {'publishedAt': '2018-02-12T16:00:01Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Behind-the-Scenes: See How Elon Musk Celebrated the Falcon Heavy Launch | National Geographic',
#     'description': 'This exclusive behind-the-scenes clip follows the SpaceX CEO and his team as they witness and celebrate the first launch of Falcon Heavy. ➡ Subscribe: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BL4dnvBytLA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BL4dnvBytLA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BL4dnvBytLA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-02-12T16:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ubdPVhXqb2OpI1EfSATvKUdWvc8',
#    'id': {'kind': 'youtube#video', 'videoId': '7tKZB2k14iY'},
#    'snippet': {'publishedAt': '2015-06-27T19:00:01Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Jealousy Bites | Brain Games',
#     'description': "There's a clear distinction between a human brain and that of a dog's, but our emotional states of mind may perform too differently, after all. ➡ Subscribe: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7tKZB2k14iY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7tKZB2k14iY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7tKZB2k14iY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-06-27T19:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'NCgrNUrlqG4-852kzeYPXV8m07U',
#    'id': {'kind': 'youtube#video', 'videoId': 'tnvbVIcZZHc'},
#    'snippet': {'publishedAt': '2012-01-09T14:02:33Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Killer Cuckoo Catfish | National Geographic',
#     'description': "A mother cichlid fish protects her young by keeping them in her mouth. But these crafty cuckoo catfish have caught on — and they're angling to turn her offspring ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tnvbVIcZZHc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tnvbVIcZZHc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tnvbVIcZZHc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2012-01-09T14:02:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'xRI68SZq8h9sRh6YNtB0o5Jeh2A',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZyYqyYAKGC0'},
#    'snippet': {'publishedAt': '2017-03-24T17:00:07Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Time Is But a Stubborn Illusion - Sneak Peek | Genius',
#     'description': 'Watch an exclusive sneak peek from the first episode of Genius, starring Geoffrey Rush as the older Einstein and Johnny Flynn as the younger. ➡ Subscribe: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZyYqyYAKGC0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZyYqyYAKGC0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZyYqyYAKGC0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-03-24T17:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'EGVKEwX7vXU9YvvsfL_Fyo7x7qg',
#    'id': {'kind': 'youtube#video', 'videoId': '_TuGK7IS8sY'},
#    'snippet': {'publishedAt': '2013-05-07T16:07:36Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Apollo Robbins on What You Don&#39;t Know | Brain Games',
#     'description': 'Deception specialist Apollo Robbins has many ways of confusing you with confidence games. ➡ Subscribe: http://bit.ly/NatGeoSubscribe About Brain Games: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_TuGK7IS8sY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_TuGK7IS8sY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_TuGK7IS8sY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-05-07T16:07:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'q9CUFPY9CleRKt3iTAmnUSjkNjs',
#    'id': {'kind': 'youtube#video', 'videoId': 'bN8F0QKsCdY'},
#    'snippet': {'publishedAt': '2015-06-04T19:00:03Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Are There White Holes? - Fan Questions | StarTalk',
#     'description': "We've all heard of black holes, but what are white holes? Neil talks about whether they actually exist. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ➡ Watch all clips ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bN8F0QKsCdY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/bN8F0QKsCdY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/bN8F0QKsCdY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-06-04T19:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PBO-7rtB_MSWL6J6nX2rMAoxQho',
#    'id': {'kind': 'youtube#video', 'videoId': 'NStn7zZKXfE'},
#    'snippet': {'publishedAt': '2019-03-28T12:00:05Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Neptune 101 | National Geographic',
#     'description': "Neptune is the most distant of the solar system's eight planets. Find out about the blue world's orbit, which of Neptune's moons is the largest, and how the planet ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NStn7zZKXfE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NStn7zZKXfE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NStn7zZKXfE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-03-28T12:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lwrDE1vrVKeiaVOLUnNn-lXgHhM',
#    'id': {'kind': 'youtube#video', 'videoId': 'vdg9gkmWsEA'},
#    'snippet': {'publishedAt': '2010-08-31T22:48:44Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Cobra vs. Mongoose | National Geographic',
#     'description': 'How does a mongoose stand up to a cobra? You might be surprised at the outcome. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ➡ Access our digital archive by ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vdg9gkmWsEA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vdg9gkmWsEA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vdg9gkmWsEA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2010-08-31T22:48:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'HZMbHhnBLXxteoHFPuCkW8YBo_w',
#    'id': {'kind': 'youtube#video', 'videoId': 'kO1kgl0p-Hw'},
#    'snippet': {'publishedAt': '2015-06-22T23:03:29Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'The Power of Positivity | Brain Games',
#     'description': "See firsthand how positive and negative reinforcement can affect a player's game on the court. ➡ Subscribe: http://bit.ly/NatGeoSubscribe #NationalGeographic ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kO1kgl0p-Hw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kO1kgl0p-Hw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kO1kgl0p-Hw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-06-22T23:03:29Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'J2meWBRH38BfDweOK_JjFyk2FlI',
#    'id': {'kind': 'youtube#video', 'videoId': 'dXJmE5yANe8'},
#    'snippet': {'publishedAt': '2019-10-18T12:00:06Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Coconut Crabs Devour Pig Carcass | Searching For Amelia',
#     'description': 'Up to three feet across, coconut crabs are the largest on earth, and they team over Nikumaroro. ➡ Subscribe: http://bit.ly/NatGeoSubscribe #NationalGeographic ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dXJmE5yANe8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dXJmE5yANe8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dXJmE5yANe8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-10-18T12:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5Var8vnpReRnbn1Mgn3A9VgAnGo',
#    'id': {'kind': 'youtube#video', 'videoId': 'sQGjiieee-A'},
#    'snippet': {'publishedAt': '2017-06-18T12:00:04Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'The Letter That Led to the Atomic Bomb | Genius',
#     'description': 'Albert Einstein becomes a United States citizen and faces a moral dilemma in service to his new country. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ➡ Watch all ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sQGjiieee-A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sQGjiieee-A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sQGjiieee-A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-06-18T12:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6p5Ww0UsNUT1k1LOH1VdA4IglsA',
#    'id': {'kind': 'youtube#video', 'videoId': 'iZm_NohNm6I'},
#    'snippet': {'publishedAt': '2016-10-27T15:00:07Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Welcome to the Gigafactory | Before the Flood',
#     'description': "Leonardo DiCaprio visits Tesla's Gigafactory and discusses with Elon Musk how the world can transition from fossil fuels to renewable energy. ➡ Subscribe: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iZm_NohNm6I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iZm_NohNm6I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iZm_NohNm6I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-10-27T15:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7N5rqNnnVAZGmxIJnQsX6M03ogY',
#    'id': {'kind': 'youtube#video', 'videoId': 'yXAKijc1Vmc'},
#    'snippet': {'publishedAt': '2009-10-28T14:06:27Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Underground LSD Lab | National Geographic',
#     'description': 'Web Exclusive: Nick Sand served hard time for running a productive underground LSD operation - and he has no regrets. ➡ Subscribe: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yXAKijc1Vmc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yXAKijc1Vmc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yXAKijc1Vmc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2009-10-28T14:06:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Kqj_5GZLCaEtzYnq4rsP5QzdGxQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'FoypZyibQro'},
#    'snippet': {'publishedAt': '2013-04-08T15:27:19Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Hand vs. Eye | Brain Games',
#     'description': 'Brain Games explores the inner workings of your brain with interactive games you can play at home, as well as experiments on the streets of a city as complex ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FoypZyibQro/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FoypZyibQro/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FoypZyibQro/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-04-08T15:27:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'c717N1Q4n5bFg_qJTYtn-v-RSdI',
#    'id': {'kind': 'youtube#video', 'videoId': 'o0W_0MuvlwQ'},
#    'snippet': {'publishedAt': '2018-11-09T13:00:08Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Caffeine 101 | National Geographic',
#     'description': 'Nearly 90% of the United States population has at least one caffeinated beverage every day. Learn about the chemistry of caffeine, how it causes increased ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/o0W_0MuvlwQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/o0W_0MuvlwQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/o0W_0MuvlwQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-11-09T13:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6zdokadRfIoMghETQ0KNilzOL8E',
#    'id': {'kind': 'youtube#video', 'videoId': 'BXyfCGDnuWs'},
#    'snippet': {'publishedAt': '2017-02-05T16:00:00Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': '109-Year-Old Veteran and His Secrets to Life Will Make You Smile | Short Film Showcase',
#     'description': "Meet Richard Overton, America's oldest veteran. In this lively short film by Matt Cooper and Rocky Conly, hear the whiskey-drinking, cigar-smoking ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BXyfCGDnuWs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BXyfCGDnuWs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BXyfCGDnuWs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-02-05T16:00:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'NxuGtOUVmP-i6ypjxng1EjR5ai4',
#    'id': {'kind': 'youtube#video', 'videoId': 'yj8sAnZ6c3g'},
#    'snippet': {'publishedAt': '2017-04-30T23:00:04Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Mozart Helps Me Think | Genius',
#     'description': 'Mileva and Albert clash over their different approaches to completing a physics assignment. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ➡ Watch all Genius Clips ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yj8sAnZ6c3g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yj8sAnZ6c3g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yj8sAnZ6c3g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-04-30T23:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'y7aM1nRbIeznT1AToRMDYrwqCfg',
#    'id': {'kind': 'youtube#video', 'videoId': 'g_JFNH_PDgo'},
#    'snippet': {'publishedAt': '2007-05-18T18:06:39Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Mystery of the Romanovs | National Geographic',
#     'description': "Russia's last Tsar and his family are betrayed from within. ➡ Subscribe: http://bit.ly/NatGeoSubscribe About National Geographic: National Geographic is the ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g_JFNH_PDgo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/g_JFNH_PDgo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/g_JFNH_PDgo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2007-05-18T18:06:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OnlbHA46owWgdOrCma-KPEeRXYM',
#    'id': {'kind': 'youtube#video', 'videoId': 'EUU0-ZpFoK4'},
#    'snippet': {'publishedAt': '2019-03-07T13:00:01Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Exoplanets 101 | National Geographic',
#     'description': 'Exoplanets challenge the notion that we are alone in the universe. Learn what types of exoplanets exist, the methods scientists employ to find them, and how ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EUU0-ZpFoK4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EUU0-ZpFoK4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EUU0-ZpFoK4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-03-07T13:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mltIWNFGZlrwtcyakTKKCfKwFI0',
#    'id': {'kind': 'youtube#video', 'videoId': 'd79ArrL8VRg'},
#    'snippet': {'publishedAt': '2009-09-22T13:48:24Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'The Orangutan and the Hound | National Geographic',
#     'description': 'When Surya the orangutan meets a hound dog by the river, the two carry on like long lost friends. Unlikely Animal Friends ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/d79ArrL8VRg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/d79ArrL8VRg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/d79ArrL8VRg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2009-09-22T13:48:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hzYR9rp36JD8c237fHjkMRqRbvE',
#    'id': {'kind': 'youtube#video', 'videoId': 'EltIpB4EtYU'},
#    'snippet': {'publishedAt': '2014-09-26T13:00:05Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Two Blind Sisters See for the First Time | Short Film Showcase',
#     'description': 'Sonia and Anita, two sisters living in India, have been blind since birth, but a simple eye operation makes it possible for them to see their mom for the first time.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EltIpB4EtYU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EltIpB4EtYU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EltIpB4EtYU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2014-09-26T13:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ECwUCLa9h9-nMiO4Ze5p4AoIfBQ',
#    'id': {'kind': 'youtube#video', 'videoId': '3qqifEdqf5g'},
#    'snippet': {'publishedAt': '2017-01-22T21:00:00Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'See the 1,000-Year-Old Windmills Still in Use Today | National Geographic',
#     'description': 'These amazing windmills are among the oldest in the world. Located in the Iranian town of Nashtifan, initially named Nish Toofan, or "storm\'s sting," the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3qqifEdqf5g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3qqifEdqf5g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3qqifEdqf5g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-01-22T21:00:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ckMKJkmuw8HkM4A70ggduLmfE3g',
#    'id': {'kind': 'youtube#video', 'videoId': '2-eVdHDcmN8'},
#    'snippet': {'publishedAt': '2014-08-27T14:08:21Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Every Detail | Doomsday Preppers',
#     'description': 'Jerry has thought of everything for his home and fortress. ➡ Subscribe: http://bit.ly/NatGeoSubscribe About National Geographic: National Geographic is the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2-eVdHDcmN8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2-eVdHDcmN8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2-eVdHDcmN8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2014-08-27T14:08:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'CAgOdXJ9uvIusbv1h6_gG5N9TKc',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ul9HIX9YBbM'},
#    'snippet': {'publishedAt': '2018-10-09T15:00:06Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Why Moths are Obsessed with Lamps | National Geographic',
#     'description': 'The story of the lamp and the moth is one of fatal attraction. The theory is that these primarily nocturnal insects have evolved to travel by the light of the moon and ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ul9HIX9YBbM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ul9HIX9YBbM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ul9HIX9YBbM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-10-09T15:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PiukVxTlIcywjtrAT4liMd-TLVk',
#    'id': {'kind': 'youtube#video', 'videoId': 'PZ1scfEbrKE'},
#    'snippet': {'publishedAt': '2007-11-13T13:23:40Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Gory Crime-Scene Cleanup | National Geographic',
#     'description': "What's the worst thing you can imagine? An inside look at a gruesome job few people could stomach. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PZ1scfEbrKE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PZ1scfEbrKE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PZ1scfEbrKE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2007-11-13T13:23:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8VmBYvf6wRHQuCK9kU8YwBZmltU',
#    'id': {'kind': 'youtube#video', 'videoId': 'HNZtDisnFa0'},
#    'snippet': {'publishedAt': '2010-04-07T16:49:53Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Growly Chihuahua | National Geographic',
#     'description': 'Cesar helps twin sisters calm down their nervous, chubby Chihuahua. ➡ Subscribe: http://bit.ly/NatGeoSubscribe About National Geographic: National ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HNZtDisnFa0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HNZtDisnFa0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HNZtDisnFa0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2010-04-07T16:49:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'McRxu85VeTH3BnvB2hkJKy_F8uQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'QUng-iHhSzU'},
#    'snippet': {'publishedAt': '2017-09-08T12:00:02Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Mohenjo Daro 101 | National Geographic',
#     'description': 'Mohenjo Daro, built at the time of the pyramids and centuries before the Roman Baths, was the largest city of the Indus Civilization. Learn facts about this ancient ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QUng-iHhSzU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QUng-iHhSzU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QUng-iHhSzU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-09-08T12:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 's0Lr_UwQLYK1cXy8itQRfpNqIqI',
#    'id': {'kind': 'youtube#video', 'videoId': '9ePic3dtykk'},
#    'snippet': {'publishedAt': '2019-03-26T12:00:04Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'How Do Honeybees Get Their Jobs? | National Geographic',
#     'description': 'Every honeybee has a job to do. Some are nurses who take care of the brood; some are janitors who clean the hive; others are foragers who gather pollen to ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9ePic3dtykk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9ePic3dtykk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9ePic3dtykk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-03-26T12:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'l5kN5LewuVOi7KNsoppVE2z-BDA',
#    'id': {'kind': 'youtube#video', 'videoId': 'Y39HxmiEt-E'},
#    'snippet': {'publishedAt': '2015-01-14T14:00:02Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Brain Magic - The Left vs. Right Illusion | Brain Games',
#     'description': 'Illusionist Eric Leclerc demonstrates his simple yet convincing disappearing coin trick to two passersby. ➡ Subscribe: http://bit.ly/NatGeoSubscribe About Brain ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Y39HxmiEt-E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Y39HxmiEt-E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Y39HxmiEt-E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-01-14T14:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'BEWI0DxusSSqbIZnf-qg8Ec9UF4',
#    'id': {'kind': 'youtube#video', 'videoId': 'aU6pxSNDPhs'},
#    'snippet': {'publishedAt': '2018-02-12T13:00:01Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Climate 101: Ozone Depletion | National Geographic',
#     'description': "Far above Earth's surface, the ozone layer helps to protect life from harmful ultraviolet radiation. Learn what CFCs are, how they have contributed to the ozone ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aU6pxSNDPhs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aU6pxSNDPhs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aU6pxSNDPhs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-02-12T13:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YWhz3PfsAxgAkTSBnLdFrCLHa0g',
#    'id': {'kind': 'youtube#video', 'videoId': 'd6EXQTSlu_0'},
#    'snippet': {'publishedAt': '2010-06-22T21:47:43Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'A Submariner&#39;s Life | National Geographic',
#     'description': 'Naked Science: 21st Century Stealth Sub : http://channel.nationalgeographic.com/series/naked-science/4254/Overview ➡ Subscribe: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/d6EXQTSlu_0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/d6EXQTSlu_0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/d6EXQTSlu_0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2010-06-22T21:47:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XA6WrDUC02guLHt55knm4h53MNw',
#    'id': {'kind': 'youtube#video', 'videoId': 'BPAbANevTqM'},
#    'snippet': {'publishedAt': '2014-04-08T15:27:28Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Eyes: The Windows to Your Health | National Geographic',
#     'description': 'Your eyes are tiny spheres of wonder. A doctor can find warning signs of high blood pressure, diabetes, and a whole range of other systemic health issues, just ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BPAbANevTqM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BPAbANevTqM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BPAbANevTqM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2014-04-08T15:27:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bNXg6HupU3I7OUt1yf53QlpT6mE',
#    'id': {'kind': 'youtube#video', 'videoId': 'bRuSmxJo_iA'},
#    'snippet': {'publishedAt': '2019-08-22T12:00:12Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Fossils 101 | National Geographic',
#     'description': 'Fossils are echoes of an ancient past. Find out about the two major categories of fossils, how fossilization occurs, and how fossils can help paint a picture of the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bRuSmxJo_iA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/bRuSmxJo_iA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/bRuSmxJo_iA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-08-22T12:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'pg0csJ59zUUeDckeYKDX1OFOoA8',
#    'id': {'kind': 'youtube#video', 'videoId': 'E7bnafuC0u4'},
#    'snippet': {'publishedAt': '2016-03-14T13:00:30Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Screams of the Falling | Brain Games',
#     'description': "Let's see how our survivors handle the stress of being dropped face-down into a 700-foot canyon. ➡ Subscribe: http://bit.ly/NatGeoSubscribe About Brain Games: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E7bnafuC0u4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/E7bnafuC0u4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/E7bnafuC0u4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-03-14T13:00:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'i88hqrTRyiqRCk0fcQE8GxBNfxM',
#    'id': {'kind': 'youtube#video', 'videoId': 'etliRLP1kxU'},
#    'snippet': {'publishedAt': '2015-12-09T19:00:01Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Crossing the Creek - Deleted Scene | Life Below Zero',
#     'description': 'Glenn must cross a cold creek in snowy weather to get to the mountains. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ➡ Watch all clips of Life Below Zero here: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/etliRLP1kxU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/etliRLP1kxU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/etliRLP1kxU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-12-09T19:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jt3cR_4g4Sa49gTnAaIRiQQVix0',
#    'id': {'kind': 'youtube#video', 'videoId': 'YXq92PItsA0'},
#    'snippet': {'publishedAt': '2013-11-13T20:04:13Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Summers in the Arctic are Tough | Life Below Zero',
#     'description': 'Glenn is out of food so he goes fishing, but the mosquitoes are the ones feasting on him. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ➡ Watch all clips of Life ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YXq92PItsA0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/YXq92PItsA0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/YXq92PItsA0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-11-13T20:04:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8tPGyYrDUP-OUFY5NFm4jSM77WA',
#    'id': {'kind': 'youtube#video', 'videoId': '4BdjxYUdJS8'},
#    'snippet': {'publishedAt': '2018-03-22T12:00:00Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'See How Ants Build Bridges in Mid-Air With Just Their Bodies | National Geographic',
#     'description': 'Army ants exhibit complex social behaviors that require group cooperation to achieve success. ➡ Subscribe: http://bit.ly/NatGeoSubscribe About National ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4BdjxYUdJS8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4BdjxYUdJS8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4BdjxYUdJS8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-03-22T12:00:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ItjUiKtUZFPnP0ZZY6m59iDarrI',
#    'id': {'kind': 'youtube#video', 'videoId': '6D81BW2CzOU'},
#    'snippet': {'publishedAt': '2015-01-12T14:00:02Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Brain Teasers | Brain Games',
#     'description': "Comedian Ben Bailey is quizzing people's common sense with a few trick questions. Think you can't be fooled? Listen carefully and play along to find out how ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6D81BW2CzOU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6D81BW2CzOU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6D81BW2CzOU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-01-12T14:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lp_n_kZC0G6Nr912fc8D23D59FE',
#    'id': {'kind': 'youtube#video', 'videoId': '_7VEWTbe5lU'},
#    'snippet': {'publishedAt': '2015-01-26T23:00:01Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Cakes of Deception | Brain Games',
#     'description': "More expensive means better, right? Not necessarily, but our brains tend to think so. In this experiment, we're going to prove how price can influence taste.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_7VEWTbe5lU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_7VEWTbe5lU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_7VEWTbe5lU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-01-26T23:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ndVJ-60QDv7SxgHzpBw4JrSxWYk',
#    'id': {'kind': 'youtube#video', 'videoId': 'S3XrKkrAZpY'},
#    'snippet': {'publishedAt': '2007-12-21T13:43:40Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'A Lesson in Aggression | Dog Whisperer',
#     'description': 'Cesar takes an aggressive German Sheppard named Troy to his long time colleague to measure his "level of aggression". ➡ Subscribe: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/S3XrKkrAZpY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/S3XrKkrAZpY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/S3XrKkrAZpY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2007-12-21T13:43:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2AU-j5GEWk-hI1KPRfQLx5t2NEI',
#    'id': {'kind': 'youtube#video', 'videoId': 'ibaMy_WvhE0'},
#    'snippet': {'publishedAt': '2014-09-14T14:00:06Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'How to Build a Bow Drill Fire | Live Free or Die: DIY',
#     'description': 'Thorn shows you how to start a fire without matches or firestarter - all you need is a forest and a bow drill. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ➡ Watch all ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ibaMy_WvhE0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ibaMy_WvhE0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ibaMy_WvhE0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2014-09-14T14:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'C-eOprb8peTwSWp8nnHBvZaVjIQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'MY1d5Saqrc4'},
#    'snippet': {'publishedAt': '2018-11-30T13:00:03Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Extremophiles 101 | National Geographic',
#     'description': 'Extremophiles are organisms that can live in exceptionally harsh environments. Find out about the different types of extremophiles, their adaptations, where they ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MY1d5Saqrc4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MY1d5Saqrc4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MY1d5Saqrc4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-11-30T13:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mGAxYeiArnx-96vP_Vg6w5h-p9I',
#    'id': {'kind': 'youtube#video', 'videoId': 'P8TT90LWYaw'},
#    'snippet': {'publishedAt': '2020-08-14T15:00:13Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'The Goblin Shark | What the Shark?',
#     'description': 'The Goblin Shark lives in the deep ocean and has a unique set of jaws for catching prey. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ➡ Get more SharkFest: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/P8TT90LWYaw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/P8TT90LWYaw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/P8TT90LWYaw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-08-14T15:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zTkJNehCKxM8z3emZtuRv2wzaJE',
#    'id': {'kind': 'youtube#video', 'videoId': 'gEl6TXrkZnk'},
#    'snippet': {'publishedAt': '2007-05-31T16:10:41Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Blood Squirting Lizard | National Geographic',
#     'description': "A lizard that squirts blood - from its eyes? Just watch, it might save the lizard's life. See all National Geographic videos: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gEl6TXrkZnk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gEl6TXrkZnk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gEl6TXrkZnk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2007-05-31T16:10:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nqycTAM7j7mfXF1ebRNKSyWrDaY',
#    'id': {'kind': 'youtube#video', 'videoId': 'oLs-UoqzLlU'},
#    'snippet': {'publishedAt': '2015-08-26T12:00:02Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Why These Headhunters Converted to Christianity | National Geographic',
#     'description': 'Some of the last surviving Naga headhunters describe how they once killed members of other tribes, a practice that ended when they converted to Christianity.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oLs-UoqzLlU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oLs-UoqzLlU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oLs-UoqzLlU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-08-26T12:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4CPIcKWHkfrL0S5bIIIz_PrKgD4',
#    'id': {'kind': 'youtube#video', 'videoId': 'Pa0SY6RYJIo'},
#    'snippet': {'publishedAt': '2007-08-13T17:13:20Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Strange Japanese Sea Creatures | National Geographic',
#     'description': "Exotic creatures lie at the bottom of Japan's Suruga Bay, including spider crabs, chimeras and lantern sharks. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Pa0SY6RYJIo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Pa0SY6RYJIo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Pa0SY6RYJIo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2007-08-13T17:13:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Ufnhp7NoeriOcWkp1ZHu0a9OBas',
#    'id': {'kind': 'youtube#video', 'videoId': 'me3U7adrQOY'},
#    'snippet': {'publishedAt': '2019-04-29T12:00:11Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Hummingbird in a Rain Storm | Hostile Planet',
#     'description': 'In the cloud forest a booted racket-tail braves a rain storm to find enough food to survive. ➡ Subscribe: http://bit.ly/NatGeoSubscribe ➡ Get More Hostile Planet: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/me3U7adrQOY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/me3U7adrQOY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/me3U7adrQOY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-04-29T12:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2i2AUBECuCLA9m_2cfAL90aP8FM',
#    'id': {'kind': 'youtube#video', 'videoId': 'U7zARByAu1c'},
#    'snippet': {'publishedAt': '2017-07-03T23:00:01Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'The Glass Frog: Ultimate Ninja Dad | Animal 24',
#     'description': 'A male glass frog is the lone protector of his eggs 24/7 until they hatch. Sometimes this means protecting them from their worst enemy. ➡ Subscribe: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U7zARByAu1c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U7zARByAu1c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U7zARByAu1c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-07-03T23:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RIMVbJ7PFjfWXO_VbnMmH5tKYFs',
#    'id': {'kind': 'youtube#video', 'videoId': 'mU38QDKmiTk'},
#    'snippet': {'publishedAt': '2015-01-11T21:00:01Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'The Ultimate Black Market Weapon | Underworld, INC',
#     'description': 'California gun dealer Nightscope sells untraceable firearms known as ghost guns for top dollar. ➡ Subscribe: http://bit.ly/NatGeoSubscribe #NationalGeographic ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mU38QDKmiTk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mU38QDKmiTk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mU38QDKmiTk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-01-11T21:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fDWWqp-85bXUQjUcme5PUYZLDDI',
#    'id': {'kind': 'youtube#video', 'videoId': 'cxrLRbkOwKs'},
#    'snippet': {'publishedAt': '2017-08-17T12:00:03Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Solar Eclipse 101 | National Geographic',
#     'description': 'A total solar eclipse happens somewhere on Earth once every year or two. What is an eclipse? Learn more about how solar eclipses happen, the four types of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cxrLRbkOwKs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cxrLRbkOwKs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cxrLRbkOwKs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'National Geographic',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-08-17T12:00:03Z'}}]}

# %% [markdown]
# #### First we need to collect VideoIds

# %%
limit = 5 
video_Ids = []
nextPageToken ="" #for 0th iteration let it be null
for i in range(limit):
    url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_Id}&maxResults=50&pageToken={nextPageToken}"
    data = json.loads(requests.get(url).text)
    for item in data['items']: 
        video_Id = item['id']['videoId']
        video_Ids.append(video_Id)           
    nextPageToken = data['nextPageToken']

# %% [markdown]
# #### Now record the required fileds for each video

# %%
for i,video_Id in enumerate(video_Ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?part=statistics,snippet&key={api_key}&id={video_Id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']      
    published_date = data['items'][0]['snippet']['publishedAt']    
    video_title =  data['items'][0]['snippet']['title']     
    video_description = data['items'][0]['snippet']['description']
    likes =  data["items"][0]["statistics"]["likeCount"]
    dislikes = data["items"][0]["statistics"]["dislikeCount"]
    views = data["items"][0]["statistics"]["viewCount"]
    comment_count = data["items"][0]["statistics"]['commentCount']
    row = [video_Id,channel_id,published_date,
           video_title,video_description,
           likes,dislikes,views,comment_count]
    data_df.loc[i]=row

# %%
data_df
# Out:
#         video_id                channel_id        published_date  \
# 0    BL4dnvBytLA  UCpVm7bg6pXKo1Pr6k5kxG9A  2018-02-12T16:00:01Z
# 1    7tKZB2k14iY  UCpVm7bg6pXKo1Pr6k5kxG9A  2015-06-27T19:00:01Z
# 2    tnvbVIcZZHc  UCpVm7bg6pXKo1Pr6k5kxG9A  2012-01-09T14:02:33Z
# 3    ZyYqyYAKGC0  UCpVm7bg6pXKo1Pr6k5kxG9A  2017-03-24T17:00:07Z
# 4    _TuGK7IS8sY  UCpVm7bg6pXKo1Pr6k5kxG9A  2013-05-07T16:07:36Z
# ..           ...                       ...                   ...
# 245  ITlo2ZBJOWU  UCpVm7bg6pXKo1Pr6k5kxG9A  2019-05-15T12:00:03Z
# 246  AGWiZLy0YuI  UCpVm7bg6pXKo1Pr6k5kxG9A  2014-05-27T14:40:18Z
# 247  aRIYP-HWqBU  UCpVm7bg6pXKo1Pr6k5kxG9A  2018-03-24T17:00:00Z
# 248  ZRN-Lu-m-oY  UCpVm7bg6pXKo1Pr6k5kxG9A  2017-06-15T12:00:02Z
# 249  PSjFHODFlRc  UCpVm7bg6pXKo1Pr6k5kxG9A  2017-05-27T12:00:02Z
#
#                                            video_title  \
# 0    Behind-the-Scenes: See How Elon Musk Celebrate...
# 1                         Jealousy Bites | Brain Games
# 2          Killer Cuckoo Catfish | National Geographic
# 3    Time Is But a Stubborn Illusion - Sneak Peek |...
# 4    Apollo Robbins on What You Don't Know | Brain ...
# ..                                                 ...
# 245  Inside the Dark World of Captive Wildlife Tour...
# 246  Dean Potter BASE Jumps With His Dog | National...
# 247  Take a Look inside China’s Giant Communal Home...
# 248  Meet a Beautiful Beetle That Loves to Eat Poop...
# 249         Shelter From a Snowstorm | Primal Survivor
#
#                                      video_description   likes dislikes  \
# 0    This exclusive behind-the-scenes clip follows ...   78419      901
# 1    There’s a clear distinction between a human br...  101602     2175
# 2    A mother cichlid fish protects her young by ke...   27191      877
# 3    Watch an exclusive sneak peek from the first e...  114180     1849
# 4    Deception specialist Apollo Robbins has many w...    3444       54
# ..                                                 ...     ...      ...
# 245  Cages, speed-breeding, fear-based training. Bl...   21983      769
# 246  Filmmaker and adventurer Dean Potter doesn't a...   15917     1600
# 247  Tucked in the rolling subtropical mountains of...    5009      187
# 248  Watch an entomologist search beneath piles of ...    2449       61
# 249  Hazen makes a temporary shelter in the trees, ...    1229       56
#
#        views comment_count
# 0    2804302          2165
# 1    5369026          6948
# 2    3863697          2096
# 3    6465115          4580
# 4     536464           119
# ..       ...           ...
# 245   706823          2295
# 246  2290474          2438
# 247   291619           255
# 248   150896           245
# 249   155242            51
#
# [250 rows x 9 columns]
